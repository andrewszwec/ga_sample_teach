# %% [markdown]
# # Sample Teach - Decision Trees and Random Forests
# ## Outcomes
# - Explain how a decision tree functions and how to build one
# - Visually represent a decision tree
# - Determine when using a decision tree is an appropriate method

# %% [markdown]
# ## Sample Decision Tree
# ### Iris Dataset

# %% [markdown]
# <figure>
#  <img src="iris_types.jpg" width="380" alt="Iris Types" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Three types of iris we are classifying (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
"""
Run this code, do not change anything
"""
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
"""
Run this code, do not change anything
"""
iris =  datasets.load_iris() 
x = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.DataFrame(iris.target, columns=['iris_type'])

# %% [markdown]
# <figure>
#  <img src="iris_petal_sepal.png" width="200" alt="Features" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> We have the dimensions of the petal and sepal (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
"""
Run this code to see dataset
"""
iris_dict = {0: 'setosa', 1: 'versicolor', 2:'virginica'}
target_labels = [iris_dict.get(t) for t in y['iris_type']]
features = x
features['targets'] = target_labels
features
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %% [markdown]
# ### Prepare the data

# %%
"""
Run this code to prepare the data for modelling
"""
# Split into training validation and test
x = iris.data
y = iris.target
from sklearn.model_selection import StratifiedShuffleSplit

# Split the data into train=80%, test=10% and valid=10%
ss = StratifiedShuffleSplit(n_splits=1, test_size=0.2)
splitter = ss.split(x, y)

for train_index, temp_index in splitter:
    #print("TRAIN:", train_index, "TEST:", test_index)
    train_x, train_y  = x[train_index], y[train_index]
    temp_x, temp_y  = x[temp_index], y[temp_index]

# Again for test and valid set, this time 50-50
ss = StratifiedShuffleSplit(n_splits=1, test_size=0.5)
splitter = ss.split(temp_x, temp_y)

for test_index, valid_index in splitter:
    #print("TRAIN:", train_index, "TEST:", test_index)
    test_x, test_y  = temp_x[test_index], temp_y[test_index]
    val_x, val_y    = temp_x[valid_index], temp_y[valid_index]
    
print('Done')
# Out:
# Done

# %%
"""
TO DO:
Use the .shape method to find the dimensions of the training, 
testing and validation sets.
They all should have 4 columns and have a total of 150 records when 
you add the records up.
"""
print('Training shape',train_x._ )
print('Testing shape',test_x._)
print('Validation shape',val_x._)
# Out:
# Training shape (120, 4)
# Testing shape (15, 4)
# Validation shape (15, 4)

# %% [markdown]
# ### Train the model
# Use Scikit Learn's DecisionTreeClassifier to train a decision tree to
# classify different types of iris. Here is the link http://scikit-learn.org/stable/modules/tree.html#tree-classification

# %%
"""
TO DO:
Use Scikit Learn's DecisionTreeClassifier to train a decision tree to
classify different types of iris. 
Input: train_x, train_y
Output: clf

"""
# Build Tree
from sklearn import tree
clf = tree.DecisionTreeClassifier(max_depth=2)
clf = clf.fit(....)

# %% [markdown]
# ### Plot Decision Tree

# %%
"""
Run this code to plot the decision tree
"""
from IPython.display import Image  
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=iris.feature_names,  
                     class_names=iris.target_names,  
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())

# %% [markdown]
# ### Find model accuracy
# Use the DecisionTreeClassifier predict method to make a prediction on the
# Validation set and use this as input into scikit learn's accuracy method. See prediction method about halfway down this page... http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier and the details of the accuracy score metric here http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score

# %%
"""
TO DO:
Use the DecisionTreeClassifier predict method to make a prediction on the
Validation set and use this as input into scikit learn's accuracy method.
Input: val_x, val_y
Output: acc

"""
from sklearn.metrics import accuracy_score
predictions = clf.predict(...)
acc = accuracy_score(... , predictions)
print('Accuracy on Validation set =', acc)
# Out:
# Accuracy on Validation set = 1.0

# %% [markdown]
# Apply the same approach to find the accuracy score on the test set.

# %%
"""
TO DO:
Apply the same approach to find the accuracy score on the test set.
Input: test_x, test_y
Output: acc

"""
predictions = clf.predict(...)
acc = accuracy_score(tes...t_y, predictions)
print('Accuracy on Test set =', acc)
# Out:
# Accuracy on Test set = 0.933333333333

# %% [markdown]
# **Well done! you have just completed the decision tree lesson.**
